# %%
import random
import json
import pickle
import numpy as np
import pandas as pd

import nltk

#nltk.download('punkt')
#nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation,Dropout
from tensorflow.keras.optimizers import SGD

lemmatizer=WordNetLemmatizer()

with open('intents.json') as json_file:
    intents = json.load(json_file)

#print(intents)

words=[]
classes=[]
documents=[]
ignore_letters=['?','!','.',',']

for intent in intents['intents']:
    for pattern in intent['patterns']:
        word_list=nltk.word_tokenize(pattern)
        words.extend(word_list)
        documents.append((word_list,intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])


words =[lemmatizer.lemmatize(word) for word in words if word not in ignore_letters]
words = sorted(set(words))
classes=sorted(set(classes))
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))



training=[]
output_empty=[0]*len(classes)

for document in documents:
    bag=[]
    word_patterns=document[0]
    words = [lemmatizer.lemmatize(word) for word in words if word and word not in ignore_letters]
    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)

    output_row=list(output_empty)
    output_row[classes.index(document[1])]=1
    training.append([bag,output_row])

random.shuffle(training)
training=np.array(training)

train_x=list(training[:,0])
train_y=list(training[:,1])
model=Sequential()
model.add(Dense(142,input_shape=(len(train_x[0]),),activation='tanh'))
model.add(Dropout(0.5))
model.add(Dense(74,activation='tanh'))
model.add(Dropout(0.4))
model.add(Dense(len(train_y[0]),activation='softmax'))

sgd=SGD(learning_rate=0.01,momentum=0.9,nesterov=True)
model.compile(loss='categorical_crossentropy',optimizer=sgd,metrics=['accuracy'])
model.compile(loss='categorical_crossentropy',metrics=['accuracy'])
hist = model.fit(np.array(train_x),np.array(train_y),epochs=100,batch_size=5,verbose=1)
model.save('chatbotmodel1.h5', hist)
print('Training Done')
# Out:
# <ipython-input-1-cb2d9d4b26c5>:60: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training=np.array(training)
# Epoch 1/100
# 27/27 [==============================] - 2s 4ms/step - loss: 3.1924 - accuracy: 0.0530
# Epoch 2/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3.0233 - accuracy: 0.1061
# Epoch 3/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2.8441 - accuracy: 0.2576
# Epoch 4/100
# 27/27 [==============================] - 0s 4ms/step - loss: 2.7468 - accuracy: 0.3409
# Epoch 5/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2.5817 - accuracy: 0.4091
# Epoch 6/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2.4326 - accuracy: 0.4318
# Epoch 7/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2.3303 - accuracy: 0.4848
# Epoch 8/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2.1898 - accuracy: 0.5530
# Epoch 9/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2.0722 - accuracy: 0.5152
# Epoch 10/100
# 27/27 [==============================] - 0s 3ms/step - loss: 1.9298 - accuracy: 0.6136
# Epoch 11/100
# 27/27 [==============================] - 0s 3ms/step - loss: 1.8305 - accuracy: 0.6439
# Epoch 12/100
# 27/27 [==============================] - 0s 3ms/step - loss: 1.7069 - accuracy: 0.6212
# Epoch 13/100
# 27/27 [==============================] - 0s 3ms/step - loss: 1.5850 - accuracy: 0.7045
# Epoch 14/100
# 27/27 [==============================] - 0s 3ms/step - loss: 1.4419 - accuracy: 0.6667
# Epoch 15/100
# 27/27 [==============================] - 0s 3ms/step - loss: 1.3387 - accuracy: 0.7803
# Epoch 16/100
# 27/27 [==============================] - 0s 3ms/step - loss: 1.2418 - accuracy: 0.7727
# Epoch 17/100
# 27/27 [==============================] - 0s 4ms/step - loss: 1.1998 - accuracy: 0.7803
# Epoch 18/100
# 27/27 [==============================] - 0s 4ms/step - loss: 1.1214 - accuracy: 0.7803
# Epoch 19/100
# 27/27 [==============================] - 0s 3ms/step - loss: 1.0424 - accuracy: 0.8106
# Epoch 20/100
# 27/27 [==============================] - 0s 3ms/step - loss: 1.0043 - accuracy: 0.8485
# Epoch 21/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.9079 - accuracy: 0.8258
# Epoch 22/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.8185 - accuracy: 0.8561
# Epoch 23/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.7983 - accuracy: 0.8182
# Epoch 24/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.7378 - accuracy: 0.8636
# Epoch 25/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6728 - accuracy: 0.8939
# Epoch 26/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6634 - accuracy: 0.8939
# Epoch 27/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6104 - accuracy: 0.9015
# Epoch 28/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.5779 - accuracy: 0.8864
# Epoch 29/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5366 - accuracy: 0.8788
# Epoch 30/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.5130 - accuracy: 0.9167
# Epoch 31/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4712 - accuracy: 0.9167
# Epoch 32/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.4222 - accuracy: 0.9015
# Epoch 33/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.3729 - accuracy: 0.9621
# Epoch 34/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.3694 - accuracy: 0.9091
# Epoch 35/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.3367 - accuracy: 0.9318
# Epoch 36/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.3321 - accuracy: 0.9318
# Epoch 37/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.3242 - accuracy: 0.9318
# Epoch 38/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.3007 - accuracy: 0.9318
# Epoch 39/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.2519 - accuracy: 0.9318
# Epoch 40/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.2481 - accuracy: 0.9470
# Epoch 41/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.2840 - accuracy: 0.9318
# Epoch 42/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.2409 - accuracy: 0.9167
# Epoch 43/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.2588 - accuracy: 0.9318
# Epoch 44/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.2237 - accuracy: 0.9242
# Epoch 45/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.2088 - accuracy: 0.9470
# Epoch 46/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.2103 - accuracy: 0.9545
# Epoch 47/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.1824 - accuracy: 0.9470
# Epoch 48/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.1901 - accuracy: 0.9470
# Epoch 49/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.2009 - accuracy: 0.9470
# Epoch 50/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.1331 - accuracy: 0.9848
# Epoch 51/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.1445 - accuracy: 0.9470
# Epoch 52/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1664 - accuracy: 0.9621
# Epoch 53/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1616 - accuracy: 0.9545
# Epoch 54/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.1394 - accuracy: 0.9545
# Epoch 55/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.1652 - accuracy: 0.9545
# Epoch 56/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.1565 - accuracy: 0.9394
# Epoch 57/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.1581 - accuracy: 0.9470
# Epoch 58/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.1351 - accuracy: 0.9545
# Epoch 59/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.1331 - accuracy: 0.9470
# Epoch 60/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.1213 - accuracy: 0.9621
# Epoch 61/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.1155 - accuracy: 0.9545
# Epoch 62/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.1108 - accuracy: 0.9470
# Epoch 63/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0902 - accuracy: 0.9773
# Epoch 64/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.1402 - accuracy: 0.9470
# Epoch 65/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.1237 - accuracy: 0.9621
# Epoch 66/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.1019 - accuracy: 0.9697
# Epoch 67/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0939 - accuracy: 0.9697
# Epoch 68/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.1157 - accuracy: 0.9394
# Epoch 69/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1113 - accuracy: 0.9318
# Epoch 70/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0849 - accuracy: 0.9621
# Epoch 71/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1135 - accuracy: 0.9470
# Epoch 72/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0832 - accuracy: 0.9621
# Epoch 73/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0737 - accuracy: 0.9697
# Epoch 74/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0941 - accuracy: 0.9545
# Epoch 75/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0988 - accuracy: 0.9394
# Epoch 76/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0909 - accuracy: 0.9621
# Epoch 77/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0876 - accuracy: 0.9621
# Epoch 78/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1001 - accuracy: 0.9545
# Epoch 79/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0761 - accuracy: 0.9773
# Epoch 80/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1052 - accuracy: 0.9470
# Epoch 81/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0749 - accuracy: 0.9621
# Epoch 82/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0948 - accuracy: 0.9697
# Epoch 83/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0938 - accuracy: 0.9545
# Epoch 84/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0789 - accuracy: 0.9697
# Epoch 85/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0884 - accuracy: 0.9545
# Epoch 86/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0850 - accuracy: 0.9545
# Epoch 87/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1000 - accuracy: 0.9470
# Epoch 88/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.1094 - accuracy: 0.9394
# Epoch 89/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.1021 - accuracy: 0.9470
# Epoch 90/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0946 - accuracy: 0.9545
# Epoch 91/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.1009 - accuracy: 0.9470
# Epoch 92/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0733 - accuracy: 0.9621
# Epoch 93/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0973 - accuracy: 0.9394
# Epoch 94/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0788 - accuracy: 0.9697
# Epoch 95/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0907 - accuracy: 0.9545
# Epoch 96/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0772 - accuracy: 0.9621
# Epoch 97/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0988 - accuracy: 0.9394
# Epoch 98/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0659 - accuracy: 0.9621
# Epoch 99/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0782 - accuracy: 0.9697
# Epoch 100/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0941 - accuracy: 0.9545
# Training Done
